# %%
#import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Add the latitudes and longitudes to a list. 
coordinates = list (lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 626

# %%
# Import the requests library.
import requests

# Import the API key.
#Won't import: try defining? 

weather_API_key = "0ebd53514de3f16cf04e362d3ca9718a"

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_API_key
print (url)
# city_url = url + "&q=" + "Boston"
# print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ebd53514de3f16cf04e362d3ca9718a

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

#Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current = city_weather["weather"][0]["description"]  
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_current})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | okhotsk
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | burica
# City not found. Skipping...
# Processing Record 4 of Set 1 | ruteng
# Processing Record 5 of Set 1 | esperance
# Processing Record 6 of Set 1 | srednekolymsk
# Processing Record 7 of Set 1 | bambous virieux
# Processing Record 8 of Set 1 | mahebourg
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | artyom
# Processing Record 11 of Set 1 | te anau
# Processing Record 12 of Set 1 | sabang
# Processing Record 13 of Set 1 | tuggurt
# City not found. Skipping...
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | puerto ayora
# Processing Record 17 of Set 1 | bluff
# Processing Record 18 of Set 1 | atuona
# Processing Record 19 of Set 1 | kavaratti
# Processing Record 20 of Set 1 | batagay-alyta
# Processing Record 21 of Set 1 | pandharpur
# Processing Record 22 of Set 1 | waipawa
# Processing Record 23 of Set 1 | cayenne
# Processing Record 24 of Set 1 | ternate
# Processing Record 25 of Set 1 | laela
# Processing Record 26 of Set 1 | jamestown
# Processing Record 27 of Set 1 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 28 of Set 1 | nawabganj
# Processing Record 29 of Set 1 | augusto correa
# Processing Record 30 of Set 1 | norman wells
# Processing Record 31 of Set 1 | koumac
# Processing Record 32 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 1 | tasiilaq
# Processing Record 34 of Set 1 | mortka
# Processing Record 35 of Set 1 | castro
# Processing Record 36 of Set 1 | sangar
# Processing Record 37 of Set 1 | hilo
# Processing Record 38 of Set 1 | saint george
# Processing Record 39 of Set 1 | sitka
# Processing Record 40 of Set 1 | barrow
# Processing Record 41 of Set 1 | walker mill
# Processing Record 42 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 1 | opuwo
# Processing Record 44 of Set 1 | lavrentiya
# Processing Record 45 of Set 1 | kapaa
# Processing Record 46 of Set 1 | verkhoyansk
# Processing Record 47 of Set 1 | ribeira grande
# Processing Record 48 of Set 1 | faya
# Processing Record 49 of Set 1 | hudson bay
# Processing Record 50 of Set 1 | bredasdorp
# Processing Record 1 of Set 2 | new norfolk
# Processing Record 2 of Set 2 | arraial do cabo
# Processing Record 3 of Set 2 | labuhan
# Processing Record 4 of Set 2 | todos santos
# Processing Record 5 of Set 2 | hermanus
# Processing Record 6 of Set 2 | wattegama
# Processing Record 7 of Set 2 | kavieng
# Processing Record 8 of Set 2 | meulaboh
# Processing Record 9 of Set 2 | nova olimpia
# Processing Record 10 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 11 of Set 2 | dikson
# Processing Record 12 of Set 2 | mar del plata
# Processing Record 13 of Set 2 | clyde river
# Processing Record 14 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 15 of Set 2 | butaritari
# Processing Record 16 of Set 2 | auki
# Processing Record 17 of Set 2 | busselton
# Processing Record 18 of Set 2 | ixtapa
# Processing Record 19 of Set 2 | malwan
# City not found. Skipping...
# Processing Record 20 of Set 2 | rikitea
# Processing Record 21 of Set 2 | san joaquin
# Processing Record 22 of Set 2 | saint-philippe
# Processing Record 23 of Set 2 | iqaluit
# Processing Record 24 of Set 2 | avarua
# Processing Record 25 of Set 2 | kenai
# Processing Record 26 of Set 2 | berlevag
# Processing Record 27 of Set 2 | vestmanna
# Processing Record 28 of Set 2 | bairnsdale
# Processing Record 29 of Set 2 | pangkalanbuun
# Processing Record 30 of Set 2 | mentok
# City not found. Skipping...
# Processing Record 31 of Set 2 | bontang
# Processing Record 32 of Set 2 | alice springs
# Processing Record 33 of Set 2 | cherskiy
# Processing Record 34 of Set 2 | nhulunbuy
# Processing Record 35 of Set 2 | chilca
# Processing Record 36 of Set 2 | east london
# Processing Record 37 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 38 of Set 2 | grand-santi
# Processing Record 39 of Set 2 | kollam
# Processing Record 40 of Set 2 | qasigiannguit
# Processing Record 41 of Set 2 | vallenar
# Processing Record 42 of Set 2 | rio gallegos
# Processing Record 43 of Set 2 | cananea
# Processing Record 44 of Set 2 | lebedinyy
# Processing Record 45 of Set 2 | cape town
# Processing Record 46 of Set 2 | port alfred
# Processing Record 47 of Set 2 | port elizabeth
# Processing Record 48 of Set 2 | thompson
# Processing Record 49 of Set 2 | dubovka
# Processing Record 50 of Set 2 | georgetown
# Processing Record 1 of Set 3 | poya
# Processing Record 2 of Set 3 | cabo san lucas
# Processing Record 3 of Set 3 | solvychegodsk
# Processing Record 4 of Set 3 | narsaq
# Processing Record 5 of Set 3 | vrangel
# Processing Record 6 of Set 3 | guerrero negro
# Processing Record 7 of Set 3 | fuerte olimpo
# Processing Record 8 of Set 3 | ahipara
# Processing Record 9 of Set 3 | belyy yar
# Processing Record 10 of Set 3 | lagoa
# Processing Record 11 of Set 3 | severo-kurilsk
# Processing Record 12 of Set 3 | manglaur
# Processing Record 13 of Set 3 | bethel
# Processing Record 14 of Set 3 | zaozerne
# Processing Record 15 of Set 3 | beyneu
# Processing Record 16 of Set 3 | provideniya
# Processing Record 17 of Set 3 | stornoway
# Processing Record 18 of Set 3 | pisco
# Processing Record 19 of Set 3 | airai
# Processing Record 20 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 21 of Set 3 | leningradskiy
# Processing Record 22 of Set 3 | maniitsoq
# Processing Record 23 of Set 3 | oneonta
# Processing Record 24 of Set 3 | tunduru
# City not found. Skipping...
# Processing Record 25 of Set 3 | chuy
# Processing Record 26 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 3 | champerico
# Processing Record 28 of Set 3 | chokurdakh
# Processing Record 29 of Set 3 | el alto
# Processing Record 30 of Set 3 | san quintin
# Processing Record 31 of Set 3 | beringovskiy
# Processing Record 32 of Set 3 | yellowknife
# Processing Record 33 of Set 3 | codrington
# Processing Record 34 of Set 3 | itarema
# Processing Record 35 of Set 3 | bubaque
# Processing Record 36 of Set 3 | bathsheba
# Processing Record 37 of Set 3 | beterou
# Processing Record 38 of Set 3 | saldanha
# Processing Record 39 of Set 3 | vila velha
# Processing Record 40 of Set 3 | troitskiy
# Processing Record 41 of Set 3 | novodugino
# Processing Record 42 of Set 3 | victoria
# Processing Record 43 of Set 3 | rudnichnyy
# Processing Record 44 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 45 of Set 3 | lerwick
# Processing Record 46 of Set 3 | kahului
# Processing Record 47 of Set 3 | sinnamary
# Processing Record 48 of Set 3 | ondjiva
# Processing Record 49 of Set 3 | yaritagua
# Processing Record 50 of Set 3 | sainte-maxime
# Processing Record 1 of Set 4 | college
# Processing Record 2 of Set 4 | punta arenas
# Processing Record 3 of Set 4 | la rochelle
# Processing Record 4 of Set 4 | rio verde de mato grosso
# Processing Record 5 of Set 4 | tiksi
# Processing Record 6 of Set 4 | aasiaat
# Processing Record 7 of Set 4 | solnechnyy
# Processing Record 8 of Set 4 | kijang
# Processing Record 9 of Set 4 | constitucion
# Processing Record 10 of Set 4 | pacific grove
# Processing Record 11 of Set 4 | sucua
# Processing Record 12 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 4 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 15 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 4 | sandviken
# Processing Record 17 of Set 4 | aksarka
# Processing Record 18 of Set 4 | thinadhoo
# Processing Record 19 of Set 4 | vostok
# Processing Record 20 of Set 4 | gornyak
# Processing Record 21 of Set 4 | lompoc
# Processing Record 22 of Set 4 | inirida
# Processing Record 23 of Set 4 | shingu
# Processing Record 24 of Set 4 | wodonga
# Processing Record 25 of Set 4 | isangel
# Processing Record 26 of Set 4 | ilfracombe
# Processing Record 27 of Set 4 | sao joao da barra
# Processing Record 28 of Set 4 | ginir
# Processing Record 29 of Set 4 | nikolskoye
# Processing Record 30 of Set 4 | hithadhoo
# Processing Record 31 of Set 4 | west plains
# Processing Record 32 of Set 4 | san jose de guanipa
# Processing Record 33 of Set 4 | paredon
# Processing Record 34 of Set 4 | buraydah
# Processing Record 35 of Set 4 | pyapon
# Processing Record 36 of Set 4 | palauig
# Processing Record 37 of Set 4 | grand gaube
# Processing Record 38 of Set 4 | cockburn town
# Processing Record 39 of Set 4 | emerald
# Processing Record 40 of Set 4 | kolondieba
# Processing Record 41 of Set 4 | stavern
# Processing Record 42 of Set 4 | hermiston
# Processing Record 43 of Set 4 | sambava
# Processing Record 44 of Set 4 | yermakovskoye
# Processing Record 45 of Set 4 | wazzan
# City not found. Skipping...
# Processing Record 46 of Set 4 | chickasha
# Processing Record 47 of Set 4 | koslan
# Processing Record 48 of Set 4 | hegang
# Processing Record 49 of Set 4 | henties bay
# Processing Record 50 of Set 4 | pangnirtung
# Processing Record 1 of Set 5 | yerbogachen
# Processing Record 2 of Set 5 | takoradi
# Processing Record 3 of Set 5 | bokspits
# City not found. Skipping...
# Processing Record 4 of Set 5 | manacor
# Processing Record 5 of Set 5 | fairbanks
# Processing Record 6 of Set 5 | hobyo
# Processing Record 7 of Set 5 | sao felix do xingu
# Processing Record 8 of Set 5 | ugoofaaru
# Processing Record 9 of Set 5 | tuktoyaktuk
# Processing Record 10 of Set 5 | abu kamal
# Processing Record 11 of Set 5 | barra do garcas
# Processing Record 12 of Set 5 | at-bashi
# Processing Record 13 of Set 5 | sao filipe
# Processing Record 14 of Set 5 | qaanaaq
# Processing Record 15 of Set 5 | san cristobal
# Processing Record 16 of Set 5 | methoni
# Processing Record 17 of Set 5 | haines junction
# Processing Record 18 of Set 5 | leshukonskoye
# Processing Record 19 of Set 5 | puerto leguizamo
# Processing Record 20 of Set 5 | zlobin
# Processing Record 21 of Set 5 | hobart
# Processing Record 22 of Set 5 | kruisfontein
# Processing Record 23 of Set 5 | souillac
# Processing Record 24 of Set 5 | tanout
# Processing Record 25 of Set 5 | kalevala
# Processing Record 26 of Set 5 | santana do livramento
# Processing Record 27 of Set 5 | kontagora
# Processing Record 28 of Set 5 | sept-iles
# Processing Record 29 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 5 | bua yai
# Processing Record 31 of Set 5 | keetmanshoop
# Processing Record 32 of Set 5 | maridi
# Processing Record 33 of Set 5 | bose
# Processing Record 34 of Set 5 | konstantinovka
# Processing Record 35 of Set 5 | bafq
# Processing Record 36 of Set 5 | khatanga
# Processing Record 37 of Set 5 | khorixas
# Processing Record 38 of Set 5 | luderitz
# Processing Record 39 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 40 of Set 5 | ambilobe
# Processing Record 41 of Set 5 | grindavik
# Processing Record 42 of Set 5 | arlit
# Processing Record 43 of Set 5 | alofi
# Processing Record 44 of Set 5 | shizunai
# Processing Record 45 of Set 5 | the valley
# Processing Record 46 of Set 5 | port hardy
# Processing Record 47 of Set 5 | le port
# Processing Record 48 of Set 5 | mecca
# Processing Record 49 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 5 | ancud
# Processing Record 1 of Set 6 | rosetta
# Processing Record 2 of Set 6 | acari
# Processing Record 3 of Set 6 | lenger
# Processing Record 4 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 6 | campbellsville
# Processing Record 7 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 6 | west wendover
# Processing Record 9 of Set 6 | hasaki
# Processing Record 10 of Set 6 | arman
# Processing Record 11 of Set 6 | zhigansk
# Processing Record 12 of Set 6 | qui nhon
# Processing Record 13 of Set 6 | kasongo-lunda
# Processing Record 14 of Set 6 | genhe
# Processing Record 15 of Set 6 | yeppoon
# Processing Record 16 of Set 6 | broome
# Processing Record 17 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 18 of Set 6 | bonthe
# Processing Record 19 of Set 6 | dunedin
# Processing Record 20 of Set 6 | taminango
# Processing Record 21 of Set 6 | benghazi
# Processing Record 22 of Set 6 | ust-nera
# Processing Record 23 of Set 6 | namalenga
# Processing Record 24 of Set 6 | mahajanga
# Processing Record 25 of Set 6 | cidreira
# Processing Record 26 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 6 | san patricio
# Processing Record 28 of Set 6 | kilindoni
# Processing Record 29 of Set 6 | barranca
# Processing Record 30 of Set 6 | boyolangu
# Processing Record 31 of Set 6 | port hedland
# Processing Record 32 of Set 6 | fukagawa
# Processing Record 33 of Set 6 | fenyi
# Processing Record 34 of Set 6 | killybegs
# Processing Record 35 of Set 6 | ojinaga
# Processing Record 36 of Set 6 | durant
# Processing Record 37 of Set 6 | san francisco
# Processing Record 38 of Set 6 | xichang
# Processing Record 39 of Set 6 | yangjiang
# Processing Record 40 of Set 6 | yoichi
# Processing Record 41 of Set 6 | carnarvon
# Processing Record 42 of Set 6 | san jose
# Processing Record 43 of Set 6 | ligayan
# Processing Record 44 of Set 6 | taoudenni
# Processing Record 45 of Set 6 | yulara
# Processing Record 46 of Set 6 | qaqortoq
# Processing Record 47 of Set 6 | sola
# Processing Record 48 of Set 6 | ponta do sol
# Processing Record 49 of Set 6 | walvis bay
# Processing Record 50 of Set 6 | alta floresta
# Processing Record 1 of Set 7 | husavik
# Processing Record 2 of Set 7 | lafiagi
# Processing Record 3 of Set 7 | sena madureira
# Processing Record 4 of Set 7 | klaksvik
# Processing Record 5 of Set 7 | catuday
# Processing Record 6 of Set 7 | effium
# Processing Record 7 of Set 7 | golden
# Processing Record 8 of Set 7 | havoysund
# Processing Record 9 of Set 7 | mount isa
# Processing Record 10 of Set 7 | makakilo city
# Processing Record 11 of Set 7 | milverton
# Processing Record 12 of Set 7 | ponezhukay
# Processing Record 13 of Set 7 | usinsk
# Processing Record 14 of Set 7 | zamosc
# Processing Record 15 of Set 7 | bengkulu
# Processing Record 16 of Set 7 | kodiak
# Processing Record 17 of Set 7 | aanekoski
# Processing Record 18 of Set 7 | camopi
# Processing Record 19 of Set 7 | fukue
# Processing Record 20 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 7 | vanimo
# Processing Record 22 of Set 7 | copiapo
# Processing Record 23 of Set 7 | okha
# Processing Record 24 of Set 7 | luau
# Processing Record 25 of Set 7 | ambon
# Processing Record 26 of Set 7 | westport
# Processing Record 27 of Set 7 | dingle
# Processing Record 28 of Set 7 | porto calvo
# Processing Record 29 of Set 7 | katsuura
# Processing Record 30 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 7 | namatanai
# Processing Record 32 of Set 7 | araouane
# Processing Record 33 of Set 7 | balkhash
# Processing Record 34 of Set 7 | kendari
# Processing Record 35 of Set 7 | ziyamet
# City not found. Skipping...
# Processing Record 36 of Set 7 | moramanga
# Processing Record 37 of Set 7 | palmer
# Processing Record 38 of Set 7 | eureka
# Processing Record 39 of Set 7 | imbituba
# Processing Record 40 of Set 7 | ames
# Processing Record 41 of Set 7 | salas
# Processing Record 42 of Set 7 | camacha
# Processing Record 43 of Set 7 | kloulklubed
# Processing Record 44 of Set 7 | maceio
# Processing Record 45 of Set 7 | marsa matruh
# Processing Record 46 of Set 7 | salta
# Processing Record 47 of Set 7 | monrovia
# Processing Record 48 of Set 7 | suntar
# Processing Record 49 of Set 7 | kaitangata
# Processing Record 50 of Set 7 | stromness
# Processing Record 1 of Set 8 | panjab
# Processing Record 2 of Set 8 | lobito
# Processing Record 3 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 8 | tungkang
# City not found. Skipping...
# Processing Record 5 of Set 8 | jiuquan
# Processing Record 6 of Set 8 | balangiga
# Processing Record 7 of Set 8 | humaita
# Processing Record 8 of Set 8 | portland
# Processing Record 9 of Set 8 | padang
# Processing Record 10 of Set 8 | olga
# Processing Record 11 of Set 8 | caravelas
# Processing Record 12 of Set 8 | tamworth
# Processing Record 13 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 14 of Set 8 | vilyuysk
# Processing Record 15 of Set 8 | satuk
# Processing Record 16 of Set 8 | nishihara
# Processing Record 17 of Set 8 | margate
# Processing Record 18 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 19 of Set 8 | jining
# Processing Record 20 of Set 8 | la asuncion
# Processing Record 21 of Set 8 | ouallam
# Processing Record 22 of Set 8 | carutapera
# Processing Record 23 of Set 8 | deputatskiy
# Processing Record 24 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 25 of Set 8 | whyalla
# Processing Record 26 of Set 8 | kuusamo
# Processing Record 27 of Set 8 | morro bay
# Processing Record 28 of Set 8 | samarai
# Processing Record 29 of Set 8 | prince rupert
# Processing Record 30 of Set 8 | aklavik
# Processing Record 31 of Set 8 | sukhobezvodnoye
# Processing Record 32 of Set 8 | funtua
# Processing Record 33 of Set 8 | vawkavysk
# Processing Record 34 of Set 8 | paamiut
# Processing Record 35 of Set 8 | mayo
# Processing Record 36 of Set 8 | mandalgovi
# Processing Record 37 of Set 8 | kinablangan
# Processing Record 38 of Set 8 | kuito
# Processing Record 39 of Set 8 | puerto escondido
# Processing Record 40 of Set 8 | patiya
# Processing Record 41 of Set 8 | fortuna
# Processing Record 42 of Set 8 | sijunjung
# Processing Record 43 of Set 8 | ilulissat
# Processing Record 44 of Set 8 | maraba
# Processing Record 45 of Set 8 | lappeenranta
# Processing Record 46 of Set 8 | agadez
# Processing Record 47 of Set 8 | aykhal
# Processing Record 48 of Set 8 | benjamin constant
# Processing Record 49 of Set 8 | male
# Processing Record 50 of Set 8 | harper
# Processing Record 1 of Set 9 | rakai
# Processing Record 2 of Set 9 | evensk
# Processing Record 3 of Set 9 | atakpame
# Processing Record 4 of Set 9 | calabozo
# Processing Record 5 of Set 9 | kedrovyy
# Processing Record 6 of Set 9 | itacare
# Processing Record 7 of Set 9 | jagatsinghapur
# Processing Record 8 of Set 9 | rio branco
# Processing Record 9 of Set 9 | albina
# Processing Record 10 of Set 9 | viedma
# Processing Record 11 of Set 9 | la ronge
# Processing Record 12 of Set 9 | yegorlykskaya
# Processing Record 13 of Set 9 | langsa
# Processing Record 14 of Set 9 | valparaiso
# Processing Record 15 of Set 9 | moree
# Processing Record 16 of Set 9 | nagato
# Processing Record 17 of Set 9 | port talbot
# Processing Record 18 of Set 9 | asau
# Processing Record 19 of Set 9 | nanortalik
# Processing Record 20 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 21 of Set 9 | alexandria
# Processing Record 22 of Set 9 | hengshui
# Processing Record 23 of Set 9 | hearst
# Processing Record 24 of Set 9 | san rafael
# Processing Record 25 of Set 9 | pevek
# Processing Record 26 of Set 9 | vila franca do campo
# Processing Record 27 of Set 9 | jagalur
# Processing Record 28 of Set 9 | salalah
# Processing Record 29 of Set 9 | wageningen
# Processing Record 30 of Set 9 | kalmunai
# Processing Record 31 of Set 9 | lancaster
# Processing Record 32 of Set 9 | tautira
# Processing Record 33 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 34 of Set 9 | roros
# Processing Record 35 of Set 9 | salinopolis
# Processing Record 36 of Set 9 | vao
# Processing Record 37 of Set 9 | faanui
# Processing Record 38 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 39 of Set 9 | kaili
# Processing Record 40 of Set 9 | ishigaki
# Processing Record 41 of Set 9 | oyama
# Processing Record 42 of Set 9 | mizdah
# Processing Record 43 of Set 9 | arua
# Processing Record 44 of Set 9 | odoyev
# Processing Record 45 of Set 9 | pontes e lacerda
# Processing Record 46 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 9 | pampa
# Processing Record 48 of Set 9 | sao pedro do sul
# Processing Record 49 of Set 9 | harbour breton
# Processing Record 50 of Set 9 | bhilai
# Processing Record 1 of Set 10 | dmytrivka
# Processing Record 2 of Set 10 | russell
# Processing Record 3 of Set 10 | ipixuna
# Processing Record 4 of Set 10 | lebu
# Processing Record 5 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 6 of Set 10 | hays
# Processing Record 7 of Set 10 | half moon bay
# Processing Record 8 of Set 10 | ostrovnoy
# Processing Record 9 of Set 10 | kuandian
# Processing Record 10 of Set 10 | plettenberg bay
# Processing Record 11 of Set 10 | yatsushiro
# Processing Record 12 of Set 10 | talant
# Processing Record 13 of Set 10 | morondava
# Processing Record 14 of Set 10 | magadan
# Processing Record 15 of Set 10 | gorontalo
# Processing Record 16 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 17 of Set 10 | mushie
# Processing Record 18 of Set 10 | sechura
# Processing Record 19 of Set 10 | prachuap khiri khan
# Processing Record 20 of Set 10 | kysyl-syr
# Processing Record 21 of Set 10 | ballina
# Processing Record 22 of Set 10 | port lincoln
# Processing Record 23 of Set 10 | ler
# Processing Record 24 of Set 10 | ingham
# Processing Record 25 of Set 10 | florianopolis
# Processing Record 26 of Set 10 | ilhabela
# Processing Record 27 of Set 10 | loreto
# Processing Record 28 of Set 10 | karasburg
# Processing Record 29 of Set 10 | iranshahr
# Processing Record 30 of Set 10 | talbahat
# Processing Record 31 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 10 | saint anthony
# Processing Record 33 of Set 10 | dicabisagan
# Processing Record 34 of Set 10 | marsassoum
# Processing Record 35 of Set 10 | torres
# Processing Record 36 of Set 10 | hovd
# Processing Record 37 of Set 10 | cozumel
# Processing Record 38 of Set 10 | svetlogorsk
# Processing Record 39 of Set 10 | nuevo progreso
# Processing Record 40 of Set 10 | coihaique
# Processing Record 41 of Set 10 | buarcos
# Processing Record 42 of Set 10 | gizo
# Processing Record 43 of Set 10 | nemuro
# Processing Record 44 of Set 10 | san andres
# Processing Record 45 of Set 10 | chama
# Processing Record 46 of Set 10 | japura
# Processing Record 47 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 48 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 49 of Set 10 | ada
# Processing Record 50 of Set 10 | batticaloa
# Processing Record 1 of Set 11 | mineros
# Processing Record 2 of Set 11 | plouzane
# Processing Record 3 of Set 11 | dhidhdhoo
# Processing Record 4 of Set 11 | kismayo
# Processing Record 5 of Set 11 | cotonou
# Processing Record 6 of Set 11 | namibe
# Processing Record 7 of Set 11 | nouadhibou
# Processing Record 8 of Set 11 | vardo
# Processing Record 9 of Set 11 | huarmey
# Processing Record 10 of Set 11 | sebring
# Processing Record 11 of Set 11 | mattru
# Processing Record 12 of Set 11 | ketchikan
# Processing Record 13 of Set 11 | tragana
# Processing Record 14 of Set 11 | yelovo
# Processing Record 15 of Set 11 | kushiro
# Processing Record 16 of Set 11 | pietersburg
# Processing Record 17 of Set 11 | byron bay
# Processing Record 18 of Set 11 | teknaf
# Processing Record 19 of Set 11 | general pico
# Processing Record 20 of Set 11 | tandil
# Processing Record 21 of Set 11 | warrnambool
# Processing Record 22 of Set 11 | tazovskiy
# Processing Record 23 of Set 11 | teslic
# Processing Record 24 of Set 11 | kivioli
# Processing Record 25 of Set 11 | geraldton
# Processing Record 26 of Set 11 | liaocheng
# Processing Record 27 of Set 11 | hit
# Processing Record 28 of Set 11 | talnakh
# Processing Record 29 of Set 11 | boca do acre
# Processing Record 30 of Set 11 | oriximina
# Processing Record 31 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 32 of Set 11 | senanga
# Processing Record 33 of Set 11 | mitsamiouli
# Processing Record 34 of Set 11 | tilichiki
# Processing Record 35 of Set 11 | sandwick
# Processing Record 36 of Set 11 | upernavik
# Processing Record 37 of Set 11 | xining
# Processing Record 38 of Set 11 | atar
# Processing Record 39 of Set 11 | coquimbo
# Processing Record 40 of Set 11 | hamilton
# Processing Record 41 of Set 11 | myrtle beach
# Processing Record 42 of Set 11 | kropotkin
# Processing Record 43 of Set 11 | luanda
# Processing Record 44 of Set 11 | gamba
# Processing Record 45 of Set 11 | cumaribo
# City not found. Skipping...
# Processing Record 46 of Set 11 | ozinki
# Processing Record 47 of Set 11 | iralaya
# Processing Record 48 of Set 11 | ghiror
# Processing Record 49 of Set 11 | kushmurun
# Processing Record 50 of Set 11 | milazzo
# Processing Record 1 of Set 12 | chapais
# Processing Record 2 of Set 12 | mooi river
# City not found. Skipping...
# Processing Record 3 of Set 12 | tanabe
# Processing Record 4 of Set 12 | hofn
# Processing Record 5 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 6 of Set 12 | sapa
# Processing Record 7 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 12 | doaba
# Processing Record 9 of Set 12 | nefteyugansk
# Processing Record 10 of Set 12 | eyl
# Processing Record 11 of Set 12 | cam ranh
# Processing Record 12 of Set 12 | roald
# Processing Record 13 of Set 12 | tha chang
# Processing Record 14 of Set 12 | barcelona
# Processing Record 15 of Set 12 | alto araguaia
# Processing Record 16 of Set 12 | kleck
# City not found. Skipping...
# Processing Record 17 of Set 12 | acapulco
# Processing Record 18 of Set 12 | mlimba
# Processing Record 19 of Set 12 | madang
# Processing Record 20 of Set 12 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 21 of Set 12 | bonfim
# Processing Record 22 of Set 12 | sur
# Processing Record 23 of Set 12 | tuatapere
# Processing Record 24 of Set 12 | borlange
# City not found. Skipping...
# Processing Record 25 of Set 12 | mumbwa
# Processing Record 26 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 27 of Set 12 | borovoy
# Processing Record 28 of Set 12 | itacoatiara
# Processing Record 29 of Set 12 | pa sang
# Processing Record 30 of Set 12 | kirksville
# Processing Record 31 of Set 12 | sorong
# Processing Record 32 of Set 12 | sumenep
# Processing Record 33 of Set 12 | mackay
# Processing Record 34 of Set 12 | cam pha
# City not found. Skipping...
# Processing Record 35 of Set 12 | lorengau
# Processing Record 36 of Set 12 | saskylakh
# Processing Record 37 of Set 12 | aliwal north
# Processing Record 38 of Set 12 | poopo
# Processing Record 39 of Set 12 | kargasok
# Processing Record 40 of Set 12 | pizarro
# Processing Record 41 of Set 12 | flinders
# Processing Record 42 of Set 12 | vaitape
# Processing Record 43 of Set 12 | ganganagar
# Processing Record 44 of Set 12 | vung tau
# Processing Record 45 of Set 12 | scarborough
# Processing Record 46 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 47 of Set 12 | sao geraldo do araguaia
# Processing Record 48 of Set 12 | sungaipenuh
# Processing Record 49 of Set 12 | elliot
# Processing Record 50 of Set 12 | kemijarvi
# Processing Record 1 of Set 13 | phan thiet
# Processing Record 2 of Set 13 | derzhavinsk
# Processing Record 3 of Set 13 | kununurra
# Processing Record 4 of Set 13 | conceicao do araguaia
# Processing Record 5 of Set 13 | touros
# Processing Record 6 of Set 13 | port blair
# Processing Record 7 of Set 13 | mount gambier
# Processing Record 8 of Set 13 | tashtyp
# Processing Record 9 of Set 13 | muros
# Processing Record 10 of Set 13 | loudeac
# Processing Record 11 of Set 13 | owando
# Processing Record 12 of Set 13 | jalu
# Processing Record 13 of Set 13 | kondinskoye
# Processing Record 14 of Set 13 | sturlic
# Processing Record 15 of Set 13 | port-gentil
# Processing Record 16 of Set 13 | micheweni
# Processing Record 17 of Set 13 | celendin
# Processing Record 18 of Set 13 | camiri
# Processing Record 19 of Set 13 | loandjili
# Processing Record 20 of Set 13 | wajima
# Processing Record 21 of Set 13 | comodoro rivadavia
# Processing Record 22 of Set 13 | tukrah
# Processing Record 23 of Set 13 | kupang
# Processing Record 24 of Set 13 | ndele
# Processing Record 25 of Set 13 | mizan teferi
# Processing Record 26 of Set 13 | bajo baudo
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Okhotsk  59.3833  143.3000     35.15        70         100
# 1           Albany  42.6001  -73.9662     42.22        40           0
# 2           Ruteng  -8.6136  120.4721     76.42        51          77
# 3        Esperance -33.8667  121.9000     60.64        63          73
# 4    Srednekolymsk  67.4500  153.6833     24.17        80          99
# 5  Bambous Virieux -20.3428   57.7575     76.21        80          11
# 6        Mahebourg -20.4081   57.7000     76.24        80           9
# 7          Ushuaia -54.8000  -68.3000     40.66        81          40
# 8           Artyom  40.4723   50.3330     60.94        72           1
# 9          Te Anau -45.4167  167.7167     60.48        61         100
#
#    Wind Speed Country                 Date Current Description
# 0       15.86      RU  2022-04-29 03:12:32     overcast clouds
# 1        5.01      US  2022-04-29 03:09:00           clear sky
# 2        1.45      ID  2022-04-29 03:12:33       broken clouds
# 3       13.02      AU  2022-04-29 03:12:33       broken clouds
# 4        6.24      RU  2022-04-29 03:12:34     overcast clouds
# 5        8.97      MU  2022-04-29 03:12:34          few clouds
# 6        9.15      MU  2022-04-29 03:10:50           clear sky
# 7       25.32      AR  2022-04-29 03:10:35    scattered clouds
# 8        5.75      AZ  2022-04-29 03:12:35           clear sky
# 9        1.83      NZ  2022-04-29 03:12:35     overcast clouds

# %%
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                    City Country      Lat       Lng  Max Temp  Humidity  \
# 0               Okhotsk      RU  59.3833  143.3000     35.15        70
# 1                Albany      US  42.6001  -73.9662     42.22        40
# 2                Ruteng      ID  -8.6136  120.4721     76.42        51
# 3             Esperance      AU -33.8667  121.9000     60.64        63
# 4         Srednekolymsk      RU  67.4500  153.6833     24.17        80
# ..                  ...     ...      ...       ...       ...       ...
# 565  Comodoro Rivadavia      AR -45.8667  -67.5000     37.26        52
# 566              Tukrah      LY  32.5341   20.5791     67.80        45
# 567              Kupang      ID -10.1667  123.5833     86.38        56
# 568               Ndele      CF   8.4109   20.6473     72.14        78
# 569        Mizan Teferi      ET   6.9833   35.5833     60.33        93
#
#      Cloudiness  Wind Speed Current Description
# 0           100       15.86     overcast clouds
# 1             0        5.01           clear sky
# 2            77        1.45       broken clouds
# 3            73       13.02       broken clouds
# 4            99        6.24     overcast clouds
# ..          ...         ...                 ...
# 565           0        5.75           clear sky
# 566         100       13.87     overcast clouds
# 567          99        1.68     overcast clouds
# 568         100        4.00     overcast clouds
# 569         100        3.49     overcast clouds
#
# [570 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
