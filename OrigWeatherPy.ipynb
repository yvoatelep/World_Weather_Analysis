# %%
#import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Add the latitudes and longitudes to a list. 
coordinates = list (lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 584

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print (url)
# city_url = url + "&q=" + "Boston"
# print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ebd53514de3f16cf04e362d3ca9718a

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# # Create an empty list to hold the weather data.
# city_data = []
# # Print the beginning of the logging.
# print("Beginning Data Retrieval     ")
# print("-----------------------------")

# # Create counters.
# record_count = 1
# set_count = 1

# #Loop through all the cities in the list.
# for i, city in enumerate(cities):

#     # Group cities in sets of 50 for logging purposes.
#     if (i % 50 == 0 and i >= 50):
#         set_count += 1
#         record_count = 1
#         time.sleep(60)

#     # Create endpoint URL with each city.
#     city_url = url + "&q=" + city.replace(" ","+")

#     # Log the URL, record, and set numbers and the city.
#     print(f"Processing Record {record_count} of Set {set_count} | {city}")
#     # Add 1 to the record count.
#     record_count += 1
    
#     # Run an API request for each of the cities.
#     try:
#         # Parse the JSON and retrieve data.
#         city_weather = requests.get(city_url).json()
#         # Parse out the needed data.
#         city_lat = city_weather["coord"]["lat"]
#         city_lng = city_weather["coord"]["lon"]
#         city_max_temp = city_weather["main"]["temp_max"]
#         city_humidity = city_weather["main"]["humidity"]
#         city_clouds = city_weather["clouds"]["all"]
#         city_wind = city_weather["wind"]["speed"]
#         city_country = city_weather["sys"]["country"]
#         # Convert the date to ISO standard.
#         city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
#         # Append the city information into city_data list.
#         city_data.append({"City": city.title(),
#                           "Lat": city_lat,
#                           "Lng": city_lng,
#                           "Max Temp": city_max_temp,
#                           "Humidity": city_humidity,
#                           "Cloudiness": city_clouds,
#                           "Wind Speed": city_wind,
#                           "Country": city_country,
#                           "Date": city_date})

# # If an error is experienced, skip the city.
#     except:
#         print("City not found. Skipping...")
#         pass

# # Indicate that Data Loading is complete.
# print("-----------------------------")
# print("Data Retrieval Complete      ")
# print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bereda
# Processing Record 2 of Set 1 | dunedin
# Processing Record 3 of Set 1 | severo-yeniseyskiy
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | cape town
# Processing Record 7 of Set 1 | urucara
# Processing Record 8 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 1 | bethel
# Processing Record 10 of Set 1 | arraial do cabo
# Processing Record 11 of Set 1 | mutsu
# Processing Record 12 of Set 1 | ponta do sol
# Processing Record 13 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 1 | kruisfontein
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | castro
# Processing Record 17 of Set 1 | gat
# Processing Record 18 of Set 1 | flinders
# Processing Record 19 of Set 1 | saint-francois
# Processing Record 20 of Set 1 | longyearbyen
# Processing Record 21 of Set 1 | bredasdorp
# Processing Record 22 of Set 1 | lompoc
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | puerto ayora
# Processing Record 25 of Set 1 | torbay
# Processing Record 26 of Set 1 | hobart
# Processing Record 27 of Set 1 | sao francisco
# Processing Record 28 of Set 1 | roma
# Processing Record 29 of Set 1 | beringovskiy
# Processing Record 30 of Set 1 | todos santos
# Processing Record 31 of Set 1 | souillac
# Processing Record 32 of Set 1 | punta arenas
# Processing Record 33 of Set 1 | rocha
# Processing Record 34 of Set 1 | hilo
# Processing Record 35 of Set 1 | siukh
# Processing Record 36 of Set 1 | cockburn town
# Processing Record 37 of Set 1 | orbetello
# Processing Record 38 of Set 1 | tuim
# Processing Record 39 of Set 1 | peniche
# Processing Record 40 of Set 1 | korem
# Processing Record 41 of Set 1 | pahrump
# Processing Record 42 of Set 1 | mokhsogollokh
# Processing Record 43 of Set 1 | verkhnevilyuysk
# Processing Record 44 of Set 1 | tiksi
# Processing Record 45 of Set 1 | samarai
# Processing Record 46 of Set 1 | atar
# Processing Record 47 of Set 1 | severo-kurilsk
# Processing Record 48 of Set 1 | hambantota
# Processing Record 49 of Set 1 | tigil
# Processing Record 50 of Set 1 | sarahan
# Processing Record 1 of Set 2 | port elizabeth
# Processing Record 2 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 2 | ugoofaaru
# Processing Record 4 of Set 2 | kapaa
# Processing Record 5 of Set 2 | dudinka
# Processing Record 6 of Set 2 | iqaluit
# Processing Record 7 of Set 2 | bluff
# Processing Record 8 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 2 | waiouru
# Processing Record 10 of Set 2 | itarema
# Processing Record 11 of Set 2 | hithadhoo
# Processing Record 12 of Set 2 | saskylakh
# Processing Record 13 of Set 2 | chokurdakh
# Processing Record 14 of Set 2 | ilulissat
# Processing Record 15 of Set 2 | zelenoborskiy
# Processing Record 16 of Set 2 | kavieng
# Processing Record 17 of Set 2 | chauk
# Processing Record 18 of Set 2 | kemijarvi
# Processing Record 19 of Set 2 | ushuaia
# Processing Record 20 of Set 2 | qaanaaq
# Processing Record 21 of Set 2 | yarada
# Processing Record 22 of Set 2 | khatanga
# Processing Record 23 of Set 2 | san cristobal
# Processing Record 24 of Set 2 | tuktoyaktuk
# Processing Record 25 of Set 2 | zomin
# Processing Record 26 of Set 2 | hermanus
# Processing Record 27 of Set 2 | mataura
# Processing Record 28 of Set 2 | faanui
# Processing Record 29 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 2 | prescott
# Processing Record 31 of Set 2 | touros
# Processing Record 32 of Set 2 | port alfred
# Processing Record 33 of Set 2 | ratanpur
# Processing Record 34 of Set 2 | bambous virieux
# Processing Record 35 of Set 2 | mwinilunga
# Processing Record 36 of Set 2 | longkou
# Processing Record 37 of Set 2 | cabo san lucas
# Processing Record 38 of Set 2 | newport
# Processing Record 39 of Set 2 | new norfolk
# Processing Record 40 of Set 2 | butaritari
# Processing Record 41 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 2 | bengkulu
# Processing Record 43 of Set 2 | effingham
# Processing Record 44 of Set 2 | port arthur
# Processing Record 45 of Set 2 | pangnirtung
# Processing Record 46 of Set 2 | am timan
# Processing Record 47 of Set 2 | tateyama
# Processing Record 48 of Set 2 | sidrolandia
# Processing Record 49 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 3 | yellowknife
# Processing Record 2 of Set 3 | tutoia
# Processing Record 3 of Set 3 | busselton
# Processing Record 4 of Set 3 | vao
# Processing Record 5 of Set 3 | huanta
# Processing Record 6 of Set 3 | denizli
# Processing Record 7 of Set 3 | maarianhamina
# Processing Record 8 of Set 3 | ribeira grande
# Processing Record 9 of Set 3 | hualmay
# Processing Record 10 of Set 3 | huadian
# Processing Record 11 of Set 3 | vaitape
# Processing Record 12 of Set 3 | japura
# Processing Record 13 of Set 3 | wanxian
# Processing Record 14 of Set 3 | aklavik
# Processing Record 15 of Set 3 | banda aceh
# Processing Record 16 of Set 3 | kilindoni
# Processing Record 17 of Set 3 | hasaki
# Processing Record 18 of Set 3 | comodoro rivadavia
# Processing Record 19 of Set 3 | cidreira
# Processing Record 20 of Set 3 | barrow
# Processing Record 21 of Set 3 | leningradskiy
# Processing Record 22 of Set 3 | camacha
# Processing Record 23 of Set 3 | vodnyy
# Processing Record 24 of Set 3 | kalawit
# Processing Record 25 of Set 3 | mount gambier
# Processing Record 26 of Set 3 | jamestown
# Processing Record 27 of Set 3 | pauini
# Processing Record 28 of Set 3 | saint-philippe
# Processing Record 29 of Set 3 | lagoa
# Processing Record 30 of Set 3 | coihaique
# Processing Record 31 of Set 3 | upernavik
# Processing Record 32 of Set 3 | chuy
# Processing Record 33 of Set 3 | barcelos
# Processing Record 34 of Set 3 | kodiak
# Processing Record 35 of Set 3 | kodaikanal
# Processing Record 36 of Set 3 | pisco
# Processing Record 37 of Set 3 | carnarvon
# Processing Record 38 of Set 3 | vakhrushev
# Processing Record 39 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 3 | saint george
# Processing Record 41 of Set 3 | aswan
# Processing Record 42 of Set 3 | talara
# Processing Record 43 of Set 3 | olaya herrera
# Processing Record 44 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 3 | ancud
# Processing Record 46 of Set 3 | walvis bay
# Processing Record 47 of Set 3 | port blair
# Processing Record 48 of Set 3 | olafsvik
# Processing Record 49 of Set 3 | hohhot
# Processing Record 50 of Set 3 | bilibino
# Processing Record 1 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 4 | cap malheureux
# Processing Record 3 of Set 4 | havelock
# Processing Record 4 of Set 4 | nouadhibou
# Processing Record 5 of Set 4 | whitehorse
# Processing Record 6 of Set 4 | victoria
# Processing Record 7 of Set 4 | huarmey
# Processing Record 8 of Set 4 | santiago del estero
# Processing Record 9 of Set 4 | montauban
# Processing Record 10 of Set 4 | namibe
# Processing Record 11 of Set 4 | porto walter
# Processing Record 12 of Set 4 | luderitz
# Processing Record 13 of Set 4 | mar del plata
# Processing Record 14 of Set 4 | copiapo
# Processing Record 15 of Set 4 | broome
# Processing Record 16 of Set 4 | inirida
# Processing Record 17 of Set 4 | berlevag
# Processing Record 18 of Set 4 | bathsheba
# Processing Record 19 of Set 4 | puri
# Processing Record 20 of Set 4 | qaqortoq
# Processing Record 21 of Set 4 | zyryanskoye
# Processing Record 22 of Set 4 | nikolayevsk-na-amure
# Processing Record 23 of Set 4 | mingshui
# Processing Record 24 of Set 4 | tessalit
# Processing Record 25 of Set 4 | jamnah
# City not found. Skipping...
# Processing Record 26 of Set 4 | boyle
# Processing Record 27 of Set 4 | oskemen
# Processing Record 28 of Set 4 | porbandar
# Processing Record 29 of Set 4 | azimur
# City not found. Skipping...
# Processing Record 30 of Set 4 | sao joao da barra
# Processing Record 31 of Set 4 | lorengau
# Processing Record 32 of Set 4 | masunga
# Processing Record 33 of Set 4 | ballina
# Processing Record 34 of Set 4 | thompson
# Processing Record 35 of Set 4 | manokwari
# Processing Record 36 of Set 4 | bonfim
# Processing Record 37 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 4 | cherskiy
# Processing Record 39 of Set 4 | antofagasta
# Processing Record 40 of Set 4 | tasiilaq
# Processing Record 41 of Set 4 | malakal
# Processing Record 42 of Set 4 | davila
# Processing Record 43 of Set 4 | lingao
# Processing Record 44 of Set 4 | urman
# Processing Record 45 of Set 4 | los llanos de aridane
# Processing Record 46 of Set 4 | ostrzeszow
# Processing Record 47 of Set 4 | senneterre
# Processing Record 48 of Set 4 | campobello di mazara
# Processing Record 49 of Set 4 | triunfo
# Processing Record 50 of Set 4 | nome
# Processing Record 1 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 2 of Set 5 | terenos
# Processing Record 3 of Set 5 | mago
# Processing Record 4 of Set 5 | kutum
# Processing Record 5 of Set 5 | yarkovo
# Processing Record 6 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 7 of Set 5 | manicore
# Processing Record 8 of Set 5 | dalbandin
# Processing Record 9 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 5 | coquimbo
# Processing Record 11 of Set 5 | oranjestad
# Processing Record 12 of Set 5 | shache
# Processing Record 13 of Set 5 | izhmorskiy
# Processing Record 14 of Set 5 | karratha
# Processing Record 15 of Set 5 | mejorada del campo
# Processing Record 16 of Set 5 | eydhafushi
# Processing Record 17 of Set 5 | san miguel
# Processing Record 18 of Set 5 | ostrovnoy
# Processing Record 19 of Set 5 | kota bahru
# Processing Record 20 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 21 of Set 5 | rio grande
# Processing Record 22 of Set 5 | bensonville
# Processing Record 23 of Set 5 | marzuq
# Processing Record 24 of Set 5 | katsuura
# Processing Record 25 of Set 5 | mahebourg
# Processing Record 26 of Set 5 | esperance
# Processing Record 27 of Set 5 | alamosa
# Processing Record 28 of Set 5 | half moon bay
# Processing Record 29 of Set 5 | daru
# Processing Record 30 of Set 5 | tokur
# Processing Record 31 of Set 5 | muisne
# Processing Record 32 of Set 5 | sibolga
# Processing Record 33 of Set 5 | burica
# City not found. Skipping...
# Processing Record 34 of Set 5 | zabinka
# City not found. Skipping...
# Processing Record 35 of Set 5 | cahabon
# Processing Record 36 of Set 5 | neiafu
# Processing Record 37 of Set 5 | avarua
# Processing Record 38 of Set 5 | linxia
# Processing Record 39 of Set 5 | awjilah
# Processing Record 40 of Set 5 | salinopolis
# Processing Record 41 of Set 5 | alcantara
# Processing Record 42 of Set 5 | itapicuru
# Processing Record 43 of Set 5 | georgetown
# Processing Record 44 of Set 5 | sataua
# City not found. Skipping...
# Processing Record 45 of Set 5 | ajdabiya
# Processing Record 46 of Set 5 | norman wells
# Processing Record 47 of Set 5 | manggar
# Processing Record 48 of Set 5 | san patricio
# Processing Record 49 of Set 5 | akim swedru
# Processing Record 50 of Set 5 | clyde river
# Processing Record 1 of Set 6 | high rock
# Processing Record 2 of Set 6 | baker city
# Processing Record 3 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 4 of Set 6 | baykit
# Processing Record 5 of Set 6 | atherton
# Processing Record 6 of Set 6 | quelimane
# Processing Record 7 of Set 6 | luquillo
# Processing Record 8 of Set 6 | casablanca
# Processing Record 9 of Set 6 | nishihara
# Processing Record 10 of Set 6 | port augusta
# Processing Record 11 of Set 6 | bahir dar
# Processing Record 12 of Set 6 | bundaberg
# Processing Record 13 of Set 6 | karpogory
# Processing Record 14 of Set 6 | terrak
# Processing Record 15 of Set 6 | jiehu
# Processing Record 16 of Set 6 | voh
# Processing Record 17 of Set 6 | umm durman
# City not found. Skipping...
# Processing Record 18 of Set 6 | ketchikan
# Processing Record 19 of Set 6 | shimoda
# Processing Record 20 of Set 6 | sibu
# Processing Record 21 of Set 6 | warmbad
# Processing Record 22 of Set 6 | bentonville
# Processing Record 23 of Set 6 | san quintin
# Processing Record 24 of Set 6 | sulangan
# Processing Record 25 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 6 | russell
# Processing Record 27 of Set 6 | kaitangata
# Processing Record 28 of Set 6 | kautokeino
# Processing Record 29 of Set 6 | lephepe
# City not found. Skipping...
# Processing Record 30 of Set 6 | koslan
# Processing Record 31 of Set 6 | paamiut
# Processing Record 32 of Set 6 | gravdal
# Processing Record 33 of Set 6 | ewa beach
# Processing Record 34 of Set 6 | charters towers
# Processing Record 35 of Set 6 | east london
# Processing Record 36 of Set 6 | lata
# Processing Record 37 of Set 6 | vidim
# Processing Record 38 of Set 6 | ust-nera
# Processing Record 39 of Set 6 | alekseyevka
# Processing Record 40 of Set 6 | arman
# Processing Record 41 of Set 6 | lalibela
# Processing Record 42 of Set 6 | ivanteyevka
# Processing Record 43 of Set 6 | salalah
# Processing Record 44 of Set 6 | gorontalo
# Processing Record 45 of Set 6 | blythe
# Processing Record 46 of Set 6 | safwah
# City not found. Skipping...
# Processing Record 47 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 48 of Set 6 | egvekinot
# Processing Record 49 of Set 6 | hofn
# Processing Record 50 of Set 6 | petropavlovka
# Processing Record 1 of Set 7 | la primavera
# Processing Record 2 of Set 7 | bud
# Processing Record 3 of Set 7 | hamilton
# Processing Record 4 of Set 7 | vila franca do campo
# Processing Record 5 of Set 7 | marrakesh
# Processing Record 6 of Set 7 | vestmannaeyjar
# Processing Record 7 of Set 7 | ierapetra
# Processing Record 8 of Set 7 | tabuk
# Processing Record 9 of Set 7 | klaksvik
# Processing Record 10 of Set 7 | vila velha
# Processing Record 11 of Set 7 | geraldton
# Processing Record 12 of Set 7 | chepareria
# Processing Record 13 of Set 7 | christchurch
# Processing Record 14 of Set 7 | dikson
# Processing Record 15 of Set 7 | rosarito
# Processing Record 16 of Set 7 | turayf
# Processing Record 17 of Set 7 | general bravo
# Processing Record 18 of Set 7 | masumbwe
# Processing Record 19 of Set 7 | pori
# Processing Record 20 of Set 7 | chernyshevskiy
# Processing Record 21 of Set 7 | tomatlan
# Processing Record 22 of Set 7 | manzil tamim
# City not found. Skipping...
# Processing Record 23 of Set 7 | nehe
# Processing Record 24 of Set 7 | aberystwyth
# Processing Record 25 of Set 7 | hirara
# Processing Record 26 of Set 7 | atasu
# Processing Record 27 of Set 7 | stromness
# Processing Record 28 of Set 7 | tatishchevo
# Processing Record 29 of Set 7 | esna
# Processing Record 30 of Set 7 | nanortalik
# Processing Record 31 of Set 7 | biloela
# Processing Record 32 of Set 7 | rayon
# Processing Record 33 of Set 7 | quartucciu
# Processing Record 34 of Set 7 | nikolskoye
# Processing Record 35 of Set 7 | grindavik
# Processing Record 36 of Set 7 | karasjok
# Processing Record 37 of Set 7 | airai
# Processing Record 38 of Set 7 | inta
# Processing Record 39 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 40 of Set 7 | dicabisagan
# Processing Record 41 of Set 7 | canto do buriti
# Processing Record 42 of Set 7 | lasa
# Processing Record 43 of Set 7 | jinji
# Processing Record 44 of Set 7 | igarka
# Processing Record 45 of Set 7 | cayenne
# Processing Record 46 of Set 7 | orlik
# Processing Record 47 of Set 7 | henties bay
# Processing Record 48 of Set 7 | filadelfia
# Processing Record 49 of Set 7 | nongpoh
# Processing Record 50 of Set 7 | derzhavinsk
# Processing Record 1 of Set 8 | acari
# Processing Record 2 of Set 8 | marang
# Processing Record 3 of Set 8 | biak
# Processing Record 4 of Set 8 | udachnyy
# Processing Record 5 of Set 8 | mujiayingzi
# Processing Record 6 of Set 8 | ulladulla
# Processing Record 7 of Set 8 | kungurtug
# Processing Record 8 of Set 8 | sarangani
# Processing Record 9 of Set 8 | mumford
# Processing Record 10 of Set 8 | lebu
# Processing Record 11 of Set 8 | shchelyayur
# City not found. Skipping...
# Processing Record 12 of Set 8 | deputatskiy
# Processing Record 13 of Set 8 | provideniya
# Processing Record 14 of Set 8 | alpena
# Processing Record 15 of Set 8 | atambua
# Processing Record 16 of Set 8 | ilo
# Processing Record 17 of Set 8 | palmer
# Processing Record 18 of Set 8 | vardo
# Processing Record 19 of Set 8 | athabasca
# Processing Record 20 of Set 8 | amarante do maranhao
# Processing Record 21 of Set 8 | mitu
# Processing Record 22 of Set 8 | krasnaya zarya
# Processing Record 23 of Set 8 | clearlake
# Processing Record 24 of Set 8 | damghan
# Processing Record 25 of Set 8 | erzin
# Processing Record 26 of Set 8 | luganville
# Processing Record 27 of Set 8 | binga
# Processing Record 28 of Set 8 | brigantine
# Processing Record 29 of Set 8 | bodden town
# Processing Record 30 of Set 8 | nhulunbuy
# Processing Record 31 of Set 8 | kahului
# Processing Record 32 of Set 8 | steinbach
# Processing Record 33 of Set 8 | caravelas
# Processing Record 34 of Set 8 | zhezkazgan
# Processing Record 35 of Set 8 | manjacaze
# Processing Record 36 of Set 8 | basse
# Processing Record 37 of Set 8 | itaituba
# Processing Record 38 of Set 8 | isangel
# Processing Record 39 of Set 8 | vostok
# Processing Record 40 of Set 8 | general roca
# Processing Record 41 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 8 | severodvinsk
# Processing Record 43 of Set 8 | remontnoye
# Processing Record 44 of Set 8 | storforshei
# Processing Record 45 of Set 8 | opelousas
# Processing Record 46 of Set 8 | fuyang
# Processing Record 47 of Set 8 | araouane
# Processing Record 48 of Set 8 | acapulco
# Processing Record 49 of Set 8 | warwick
# Processing Record 50 of Set 8 | miroslav
# Processing Record 1 of Set 9 | waddan
# Processing Record 2 of Set 9 | abbeville
# Processing Record 3 of Set 9 | anadyr
# Processing Record 4 of Set 9 | diffa
# Processing Record 5 of Set 9 | tuatapere
# Processing Record 6 of Set 9 | sitka
# Processing Record 7 of Set 9 | mangai
# Processing Record 8 of Set 9 | husavik
# Processing Record 9 of Set 9 | george
# Processing Record 10 of Set 9 | yulara
# Processing Record 11 of Set 9 | moree
# Processing Record 12 of Set 9 | guerrero negro
# Processing Record 13 of Set 9 | dingle
# Processing Record 14 of Set 9 | xanlar
# Processing Record 15 of Set 9 | tahta
# Processing Record 16 of Set 9 | litoral del san juan
# City not found. Skipping...
# Processing Record 17 of Set 9 | kayerkan
# Processing Record 18 of Set 9 | pacific grove
# Processing Record 19 of Set 9 | havoysund
# Processing Record 20 of Set 9 | tautira
# Processing Record 21 of Set 9 | eura
# Processing Record 22 of Set 9 | novoagansk
# Processing Record 23 of Set 9 | kailua
# Processing Record 24 of Set 9 | alofi
# Processing Record 25 of Set 9 | jacareacanga
# Processing Record 26 of Set 9 | north bend
# Processing Record 27 of Set 9 | maragogi
# Processing Record 28 of Set 9 | lubango
# Processing Record 29 of Set 9 | aitape
# Processing Record 30 of Set 9 | linjiang
# Processing Record 31 of Set 9 | peachland
# Processing Record 32 of Set 9 | kaeo
# Processing Record 33 of Set 9 | alyangula
# Processing Record 34 of Set 9 | muros
# Processing Record 35 of Set 9 | kilmez
# City not found. Skipping...
# Processing Record 36 of Set 9 | salinas
# Processing Record 37 of Set 9 | ayan
# Processing Record 38 of Set 9 | celestun
# Processing Record 39 of Set 9 | ozernovskiy
# Processing Record 40 of Set 9 | toktogul
# Processing Record 41 of Set 9 | turba
# Processing Record 42 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 43 of Set 9 | berbera
# Processing Record 44 of Set 9 | nanakuli
# Processing Record 45 of Set 9 | dourbali
# Processing Record 46 of Set 9 | muswellbrook
# Processing Record 47 of Set 9 | port hedland
# Processing Record 48 of Set 9 | makungu
# Processing Record 49 of Set 9 | nenjiang
# Processing Record 50 of Set 9 | yirol
# City not found. Skipping...
# Processing Record 1 of Set 10 | bagratashen
# Processing Record 2 of Set 10 | meulaboh
# Processing Record 3 of Set 10 | mogadishu
# Processing Record 4 of Set 10 | sabang
# Processing Record 5 of Set 10 | baboua
# City not found. Skipping...
# Processing Record 6 of Set 10 | taber
# Processing Record 7 of Set 10 | turukhansk
# Processing Record 8 of Set 10 | zharkovskiy
# Processing Record 9 of Set 10 | san andres
# Processing Record 10 of Set 10 | luhyny
# Processing Record 11 of Set 10 | gillette
# Processing Record 12 of Set 10 | avera
# Processing Record 13 of Set 10 | verkhoyansk
# Processing Record 14 of Set 10 | maxixe
# Processing Record 15 of Set 10 | kushima
# Processing Record 16 of Set 10 | seshcha
# Processing Record 17 of Set 10 | karakendzha
# City not found. Skipping...
# Processing Record 18 of Set 10 | saldanha
# Processing Record 19 of Set 10 | kurilsk
# Processing Record 20 of Set 10 | altamont
# Processing Record 21 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 10 | dekar
# Processing Record 23 of Set 10 | paredon
# Processing Record 24 of Set 10 | klyuchi
# Processing Record 25 of Set 10 | lakes entrance
# Processing Record 26 of Set 10 | cambridge
# Processing Record 27 of Set 10 | tepechitlan
# Processing Record 28 of Set 10 | pishva
# Processing Record 29 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 30 of Set 10 | great falls
# Processing Record 31 of Set 10 | kati
# Processing Record 32 of Set 10 | marsa matruh
# Processing Record 33 of Set 10 | zuenoula
# Processing Record 34 of Set 10 | khandyga
# Processing Record 35 of Set 10 | lavrentiya
# Processing Record 36 of Set 10 | nakusp
# Processing Record 37 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 38 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 10 | monte alegre de sergipe
# Processing Record 40 of Set 10 | adrar
# Processing Record 41 of Set 10 | soyo
# Processing Record 42 of Set 10 | roberval
# Processing Record 43 of Set 10 | yuksekova
# Processing Record 44 of Set 10 | halifax
# Processing Record 45 of Set 10 | darab
# Processing Record 46 of Set 10 | senador pompeu
# Processing Record 47 of Set 10 | nyaunglebin
# Processing Record 48 of Set 10 | pangody
# Processing Record 49 of Set 10 | ust-tsilma
# Processing Record 50 of Set 10 | harlingen
# Processing Record 1 of Set 11 | omboue
# Processing Record 2 of Set 11 | clearwater
# Processing Record 3 of Set 11 | novyy urengoy
# Processing Record 4 of Set 11 | agadir
# Processing Record 5 of Set 11 | kaseda
# Processing Record 6 of Set 11 | ephrata
# Processing Record 7 of Set 11 | luanda
# Processing Record 8 of Set 11 | galle
# Processing Record 9 of Set 11 | santa rosa
# Processing Record 10 of Set 11 | kalmunai
# Processing Record 11 of Set 11 | tanquian
# City not found. Skipping...
# Processing Record 12 of Set 11 | sirjan
# Processing Record 13 of Set 11 | solnechnyy
# Processing Record 14 of Set 11 | lazaro cardenas
# Processing Record 15 of Set 11 | mayo
# Processing Record 16 of Set 11 | ulaanbaatar
# Processing Record 17 of Set 11 | finschhafen
# Processing Record 18 of Set 11 | chapais
# Processing Record 19 of Set 11 | zapolyarnyy
# Processing Record 20 of Set 11 | pervomayskiy
# Processing Record 21 of Set 11 | shingu
# Processing Record 22 of Set 11 | jiangyou
# Processing Record 23 of Set 11 | korla
# Processing Record 24 of Set 11 | gotsu
# Processing Record 25 of Set 11 | omsukchan
# Processing Record 26 of Set 11 | chumikan
# Processing Record 27 of Set 11 | fortuna
# Processing Record 28 of Set 11 | barra do garcas
# Processing Record 29 of Set 11 | komsomolskiy
# Processing Record 30 of Set 11 | sept-iles
# Processing Record 31 of Set 11 | san felipe
# Processing Record 32 of Set 11 | rincon
# Processing Record 33 of Set 11 | de-kastri
# Processing Record 34 of Set 11 | naifaru
# Processing Record 35 of Set 11 | victoria point
# Processing Record 36 of Set 11 | sorong
# Processing Record 37 of Set 11 | saquena
# Processing Record 38 of Set 11 | darnah
# Processing Record 39 of Set 11 | ust-omchug
# Processing Record 40 of Set 11 | paita
# Processing Record 41 of Set 11 | port hope
# Processing Record 42 of Set 11 | asau
# Processing Record 43 of Set 11 | smithers
# Processing Record 44 of Set 11 | morshansk
# Processing Record 45 of Set 11 | kilkenny
# Processing Record 46 of Set 11 | deer lake
# Processing Record 47 of Set 11 | vestmanna
# Processing Record 48 of Set 11 | la ciotat
# Processing Record 49 of Set 11 | dumas
# Processing Record 50 of Set 11 | karamay
# City not found. Skipping...
# Processing Record 1 of Set 12 | kalamakion
# City not found. Skipping...
# Processing Record 2 of Set 12 | bograd
# Processing Record 3 of Set 12 | mirabad
# Processing Record 4 of Set 12 | kargil
# Processing Record 5 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 6 of Set 12 | gigmoto
# Processing Record 7 of Set 12 | kupang
# Processing Record 8 of Set 12 | abatskoye
# Processing Record 9 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 10 of Set 12 | dogondoutchi
# Processing Record 11 of Set 12 | houma
# Processing Record 12 of Set 12 | monrovia
# Processing Record 13 of Set 12 | puerto colombia
# Processing Record 14 of Set 12 | oriximina
# Processing Record 15 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 16 of Set 12 | redmond
# Processing Record 17 of Set 12 | lar
# Processing Record 18 of Set 12 | grafton
# Processing Record 19 of Set 12 | vandra
# Processing Record 20 of Set 12 | alekseyevsk
# Processing Record 21 of Set 12 | gobabis
# Processing Record 22 of Set 12 | portland
# Processing Record 23 of Set 12 | riverton
# Processing Record 24 of Set 12 | nzega
# Processing Record 25 of Set 12 | genhe
# Processing Record 26 of Set 12 | talnakh
# Processing Record 27 of Set 12 | chumphon
# Processing Record 28 of Set 12 | andra
# Processing Record 29 of Set 12 | belmonte
# Processing Record 30 of Set 12 | onega
# Processing Record 31 of Set 12 | macusani
# Processing Record 32 of Set 12 | naze
# Processing Record 33 of Set 12 | grand-santi
# Processing Record 34 of Set 12 | brae
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0              Bereda  43.2686   -7.5406     57.58        89          97
# 1             Dunedin -45.8742  170.5036     52.81        71           3
# 2  Severo-Yeniseyskiy  60.3725   93.0408     25.07        94          88
# 3              Albany  42.6001  -73.9662     51.58        46          63
# 4              Atuona  -9.8000 -139.0333     78.67        77          44
# 5           Cape Town -33.9258   18.4232     65.91        62           1
# 6             Urucara  -2.5364  -57.7600     84.69        74         100
# 7              Bethel  41.3712  -73.4140     55.76        53          75
# 8     Arraial Do Cabo -22.9661  -42.0278     84.06        65           0
# 9               Mutsu  41.2894  141.2169     47.35        64           1
#
#    Wind Speed Country                 Date
# 0        2.75      ES  2022-04-27 18:08:44
# 1        5.01      NZ  2022-04-27 18:03:36
# 2        4.09      RU  2022-04-27 18:08:45
# 3        8.01      US  2022-04-27 18:06:43
# 4       22.39      PF  2022-04-27 18:08:45
# 5        8.01      ZA  2022-04-27 18:08:46
# 6        3.09      BR  2022-04-27 18:08:47
# 7       14.97      US  2022-04-27 18:07:32
# 8       11.50      BR  2022-04-27 18:08:48
# 9       13.49      JP  2022-04-27 18:08:48

# %%
new_column_order = ["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                    City Country                 Date      Lat       Lng  \
# 0                Bereda      ES  2022-04-27 18:08:44  43.2686   -7.5406
# 1               Dunedin      NZ  2022-04-27 18:03:36 -45.8742  170.5036
# 2    Severo-Yeniseyskiy      RU  2022-04-27 18:08:45  60.3725   93.0408
# 3                Albany      US  2022-04-27 18:06:43  42.6001  -73.9662
# 4                Atuona      PF  2022-04-27 18:08:45  -9.8000 -139.0333
# ..                  ...     ...                  ...      ...       ...
# 532               Onega      RU  2022-04-27 18:23:47  63.9061   38.1404
# 533            Macusani      PE  2022-04-27 18:23:48 -14.0833  -70.4333
# 534                Naze      JP  2022-04-27 18:20:04  28.3667  129.4833
# 535         Grand-Santi      GF  2022-04-27 18:23:49   4.2500  -54.3833
# 536                Brae      GB  2022-04-27 18:23:50  60.3964   -1.3530
#
#      Max Temp  Humidity  Cloudiness  Wind Speed
# 0       57.58        89          97        2.75
# 1       52.81        71           3        5.01
# 2       25.07        94          88        4.09
# 3       51.58        46          63        8.01
# 4       78.67        77          44       22.39
# ..        ...       ...         ...         ...
# 532     19.62        86          34        3.29
# 533     52.41        48          37        3.91
# 534     70.72        88         100        8.16
# 535     85.91        67          91        0.60
# 536     44.62        68          79        9.60
#
# [537 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
#Extract relevant fields from the DataFrame for plotting#
lats = city_data_df["Lat"]
max_temps= city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed" + time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.

def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    
    
    # Run regression on  hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept

    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Create a scatter plot of the x and y values.
    plt.scatter(x_values,y_values)
    # Plot the regression line with the x-values and the y coordinates based on the intercept and slope.
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation and add its coordinates.
    plt.annotate(line_eq, (10,40), fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13 =city_data_df.loc[13]
index13
# Out:
# City                       Castro
# Country                        BR
# Date          2022-04-27 18:08:49
# Lat                      -24.7911
# Lng                      -50.0119
# Max Temp                    78.44
# Humidity                       52
# Cloudiness                      2
# Wind Speed                   7.92
# Name: 13, dtype: object

# %%
#Use loc to determine information in one column of a data frame

city_data_df["Lat"] >= 0
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 532     True
# 533    False
# 534     True
# 535     True
# 536     True
# Name: Lat, Length: 537, dtype: bool

# %%
#Use loc to retrieve specific information from one column of a data frame
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()
# Out:
#                  City Country                 Date      Lat       Lng  \
# 0              Bereda      ES  2022-04-27 18:08:44  43.2686   -7.5406
# 2  Severo-Yeniseyskiy      RU  2022-04-27 18:08:45  60.3725   93.0408
# 3              Albany      US  2022-04-27 18:06:43  42.6001  -73.9662
# 7              Bethel      US  2022-04-27 18:07:32  41.3712  -73.4140
# 9               Mutsu      JP  2022-04-27 18:08:48  41.2894  141.2169
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     57.58        89          97        2.75
# 2     25.07        94          88        4.09
# 3     51.58        46          63        8.01
# 7     55.76        53          75       14.97
# 9     47.35        64           1       13.49

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,20))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(-20,50))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Humidtiy', '% Humidity',(-50,15))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function
plot_linear_regression(x_values, y_values,
                   'Linear Regression on the Northern Hemisphere \
                    for % Cloudiness', '% Cloudiness',(10,55))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function
plot_linear_regression(x_values, y_values,
                   'Linear Regression on the Southern Hemisphere \
                    for % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed', 'Wind Speed',(40,35))

# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID                City Country                 Date      Lat  \
# 0        0              Bereda      ES  2022-04-27 18:08:44  43.2686
# 1        1             Dunedin      NZ  2022-04-27 18:03:36 -45.8742
# 2        2  Severo-Yeniseyskiy      RU  2022-04-27 18:08:45  60.3725
# 3        3              Albany      US  2022-04-27 18:06:43  42.6001
# 4        4              Atuona      PF  2022-04-27 18:08:45  -9.8000
#
#         Lng  Max Temp  Humidity  Cloudiness  Wind Speed
# 0   -7.5406     57.58        89          97        2.75
# 1  170.5036     52.81        71           3        5.01
# 2   93.0408     25.07        94          88        4.09
# 3  -73.9662     51.58        46          63        8.01
# 4 -139.0333     78.67        77          44       22.39

# %%
#check the data types
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
# Assign the figure variable.
fig = gmaps.figure()
# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=temps)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)

# %%
preferred_cities_df.count()
# Out:
# City_ID       196
# City          196
# Country       195
# Date          196
# Lat           196
# Lng           196
# Max Temp      196
# Humidity      196
# Cloudiness    196
# Wind Speed    196
# dtype: int64
